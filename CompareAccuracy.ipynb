# %%
# %matplotlib inline

# %%
# %time %run CompareAccuracy.py
# Out:
# Done
# CPU times: user 3min 24s, sys: 7.4 s, total: 3min 31s
# Wall time: 3min 35s

# %%
print len(min_dist_to_nodes)
# Out:
# 370

# %%
from matplotlib import pyplot as plt

# %%
plt.hist(distance_to_worms, bins=50, cumulative=False)
plt.xlabel('Distance(Meters)')
plt.ylabel('Count')
plt.title('Histogram of Distances from Worm Points to EQs')
plt.savefig('ADKsBGAFairWormHistogram.png')

# %%
plt.hist(distance_to_eulers, bins=50, cumulative=False)
plt.xlabel('Distance(Meters)')
plt.ylabel('Count')
plt.title('Histogram of Distances from Euler Points to EQs')
plt.savefig('ADKsBGAFairEulerHistogram.png')

# %%
depth_array = np.array(depth_analysis)

# %%
ax = plt.subplot(211)
plt.subplots_adjust(hspace=0.7)

plt.scatter(depth_array[:,0],depth_array[:,1],c='red',alpha=0.8,marker="v")
plt.xlabel("Depth")
plt.ylabel("Distance from eq")
ax.set_title('Worms')

ax = plt.subplot(212)
plt.scatter(depth_array[:,0],depth_array[:,2],c='blue',alpha=0.8)
plt.xlabel("Depth")
plt.ylabel("Distance from eq")
ax.set_title('Eulers')
#plt.legend()
plt.savefig("Depth_vs_Distance_BGA.png")

# %%
print depth_array.shape
# Out:
# (402, 3)

# %%
import seaborn as sns

# %%
ax = plt.subplot(211)
sns.set(style="dark")
rs = depth_array[:,0]

ax = plt.subplot(212)

# %%
foo[idxs].shape
# Out:
# (987, 3)
