# %%
# %matplotlib inline

# %%
import sys
sys.setrecursionlimit(10000)

# %%
# %time %run CompareEulerEQs.py
# Out:
# /bonzo_pool/home/frank/.virtualenvs/korin_worming/local/lib/python2.7/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /bonzo_pool/home/frank/.virtualenvs/korin_worming/local/lib/python2.7/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# ...

# %%
from matplotlib import pyplot as plt

# %%
ninety_percent_depth_rms = 2131.
max_dist_in_hist = np.max(min_dist_to_nodes)
h_box_fraction = ninety_percent_depth_rms / max_dist_in_hist
plt.hist(min_dist_to_nodes, bins=50, cumulative=False, color='b', edgecolor='black')
axes=plt.gca()
axes.set_ylim(0,20)
axes.set_xlim(0,10000)
plt.yticks(range(0,21,5))
plt.xlabel('Distance (meters)')
plt.ylabel('Count')
plt.axhspan(0,20,xmax=h_box_fraction,alpha=0.3,color='b')
plt.title('Histogram of Distances from Mag Euler Points to EQs')
plt.savefig('ADK_PSG_ANF_5km_EQsDistToEulers.png')

# %%
depth_array = np.array(depth_analysis)

# %%
plt.scatter(depth_array[:,0],depth_array[:,1])
plt.xlabel("Depth")
plt.ylabel("Distance from Euler point")
plt.savefig("Euler_Depth_Analysis_BGA.png")

# %%
len(min_dist_to_nodes)
# Out:
# 456
